# %%
import sys
sys.path.insert(0,'../src/data')
from WarmUp import main_test

# %%
#print(sys.path)
# Out:
# ['../src/data', '../src/data', '../src/data', '../src/data', '../../ift6758', '../src/data', '../src/data', '../src/data', 'C:\\Users\\timot\\Desktop\\Mila\\Courses\\IFT6758\\Project\\Project Code\\hockey\\notebooks', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env\\python39.zip', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env\\DLLs', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env\\lib', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env', '', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env\\lib\\site-packages', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env\\lib\\site-packages\\win32', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env\\lib\\site-packages\\win32\\lib', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env\\lib\\site-packages\\Pythonwin', 'C:\\Users\\timot\\.conda\\envs\\ift6758-conda-env\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\timot\\.ipython']

# %%
main_test()
# Out:
# Retrieving data from 'https://www.hockey-reference.com/leagues/NHL_2017_goalies.html'...
# Created Directry
# Data saved
# Save as data/WarmUp/Goalie Performance Ranking.jpg
# Plot Created
# Warm Up Complete
