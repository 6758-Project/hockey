# %%
from tidy_data import get_events_information

# %%
get_events_information(game_id = "2020020001")
# Out:
#      id  event_index     game_id  type secondary_type  \
# 0    53            4  2020020001  SHOT     Wrist Shot
# 1     9            7  2020020001  SHOT     Wrist Shot
# 2    55           10  2020020001  SHOT       Backhand
# 3    62           22  2020020001  SHOT      Snap Shot
# 4    65           27  2020020001  SHOT      Slap Shot
# ..  ...          ...         ...   ...            ...
# 56  531          260  2020020001  SHOT       Backhand
# 57  534          272  2020020001  SHOT       Backhand
# 58  535          274  2020020001  SHOT     Wrist Shot
# 59  537          278  2020020001  SHOT     Wrist Shot
# 60  541          282  2020020001  SHOT       Backhand
#
#                                          description    code  period  \
# 0   Travis Konecny Wrist Shot saved by Tristan Jarry   PHI53       1
# 1     Evan Rodrigues Wrist Shot saved by Carter Hart    PHI9       1
# 2       Joel Farabee Backhand saved by Tristan Jarry   PHI55       1
# ...
